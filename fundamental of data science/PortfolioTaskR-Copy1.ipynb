# %% [markdown]
# # Task 1

# %%
library(tidyr)
library(dplyr)
library(reshape2)
library(tidyverse)
library(datasets)
library(modeest)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: 'reshape2'
#
#
# The following object is masked from 'package:tidyr':
#
#     smiths
#
#
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.5     v stringr 1.4.0
# v readr   2.1.1     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Registered S3 method overwritten by 'rmutil':
#   method         from
#   print.response httr

# %%
# Using tidyr to load dataset who
who_data  = tidyr::who
who_data
# Out:
#      country     iso2 iso3 year new_sp_m014 new_sp_m1524 new_sp_m2534
# 1    Afghanistan AF   AFG  1980  NA          NA           NA
# 2    Afghanistan AF   AFG  1981  NA          NA           NA
# 3    Afghanistan AF   AFG  1982  NA          NA           NA
# 4    Afghanistan AF   AFG  1983  NA          NA           NA
# 5    Afghanistan AF   AFG  1984  NA          NA           NA
# 6    Afghanistan AF   AFG  1985  NA          NA           NA
# 7    Afghanistan AF   AFG  1986  NA          NA           NA
# 8    Afghanistan AF   AFG  1987  NA          NA           NA
# 9    Afghanistan AF   AFG  1988  NA          NA           NA
# 10   Afghanistan AF   AFG  1989  NA          NA           NA
# 11   Afghanistan AF   AFG  1990  NA          NA           NA
# 12   Afghanistan AF   AFG  1991  NA          NA           NA
# 13   Afghanistan AF   AFG  1992  NA          NA           NA
# 14   Afghanistan AF   AFG  1993  NA          NA           NA
# ...

# %% [markdown]
# ## Q1

# %%
who1 <-who_data %>%
  pivot_longer(
    cols = new_sp_m014:newrel_f65,
    names_to = "key",
    values_to = "value",
    values_drop_na = TRUE
  ) 
who1
# Out:
#       country     iso2 iso3 year key          value
# 1     Afghanistan AF   AFG  1997 new_sp_m014    0
# 2     Afghanistan AF   AFG  1997 new_sp_m1524  10
# 3     Afghanistan AF   AFG  1997 new_sp_m2534   6
# 4     Afghanistan AF   AFG  1997 new_sp_m3544   3
# 5     Afghanistan AF   AFG  1997 new_sp_m4554   5
# 6     Afghanistan AF   AFG  1997 new_sp_m5564   2
# 7     Afghanistan AF   AFG  1997 new_sp_m65     0
# 8     Afghanistan AF   AFG  1997 new_sp_f014    5
# 9     Afghanistan AF   AFG  1997 new_sp_f1524  38
# 10    Afghanistan AF   AFG  1997 new_sp_f2534  36
# 11    Afghanistan AF   AFG  1997 new_sp_f3544  14
# 12    Afghanistan AF   AFG  1997 new_sp_f4554   8
# 13    Afghanistan AF   AFG  1997 new_sp_f5564   0
# 14    Afghanistan AF   AFG  1997 new_sp_f65     1
# 15    Afghanistan AF   AFG  1998 new_sp_m014   30
# 16    Afghanistan AF   AFG  1998 new_sp_m1524 129
# 17    Afghanistan AF   AFG  1998 new_sp_m2534 128
# 18    Afghanistan AF   AFG  1998 new_sp_m3544  90
# ...

# %% [markdown]
# ## Q2

# %%
who2 <-who1 %>% mutate(key = str_replace(key, "newrel","new_rel"))
who2
# Out:
#       country     iso2 iso3 year key           value
# 1     Afghanistan AF   AFG  1997 new_sp_m014     0
# 2     Afghanistan AF   AFG  1997 new_sp_m1524   10
# 3     Afghanistan AF   AFG  1997 new_sp_m2534    6
# 4     Afghanistan AF   AFG  1997 new_sp_m3544    3
# 5     Afghanistan AF   AFG  1997 new_sp_m4554    5
# 6     Afghanistan AF   AFG  1997 new_sp_m5564    2
# 7     Afghanistan AF   AFG  1997 new_sp_m65      0
# 8     Afghanistan AF   AFG  1997 new_sp_f014     5
# 9     Afghanistan AF   AFG  1997 new_sp_f1524   38
# 10    Afghanistan AF   AFG  1997 new_sp_f2534   36
# 11    Afghanistan AF   AFG  1997 new_sp_f3544   14
# 12    Afghanistan AF   AFG  1997 new_sp_f4554    8
# 13    Afghanistan AF   AFG  1997 new_sp_f5564    0
# 14    Afghanistan AF   AFG  1997 new_sp_f65      1
# 15    Afghanistan AF   AFG  1998 new_sp_m014    30
# 16    Afghanistan AF   AFG  1998 new_sp_m1524  129
# 17    Afghanistan AF   AFG  1998 new_sp_m2534  128
# ...

# %% [markdown]
# ## Q3

# %%
who3 <- who2 %>% separate(key,c("new", "type", "sexage"),sep="_")
who3
# Out:
#       country     iso2 iso3 year new type sexage value
# 1     Afghanistan AF   AFG  1997 new sp   m014     0
# 2     Afghanistan AF   AFG  1997 new sp   m1524   10
# 3     Afghanistan AF   AFG  1997 new sp   m2534    6
# 4     Afghanistan AF   AFG  1997 new sp   m3544    3
# 5     Afghanistan AF   AFG  1997 new sp   m4554    5
# 6     Afghanistan AF   AFG  1997 new sp   m5564    2
# 7     Afghanistan AF   AFG  1997 new sp   m65      0
# 8     Afghanistan AF   AFG  1997 new sp   f014     5
# 9     Afghanistan AF   AFG  1997 new sp   f1524   38
# 10    Afghanistan AF   AFG  1997 new sp   f2534   36
# 11    Afghanistan AF   AFG  1997 new sp   f3544   14
# 12    Afghanistan AF   AFG  1997 new sp   f4554    8
# 13    Afghanistan AF   AFG  1997 new sp   f5564    0
# 14    Afghanistan AF   AFG  1997 new sp   f65      1
# 15    Afghanistan AF   AFG  1998 new sp   m014    30
# 16    Afghanistan AF   AFG  1998 new sp   m1524  129
# 17    Afghanistan AF   AFG  1998 new sp   m2534  128
# ...

# %% [markdown]
# ## Q4

# %%
who4 <-who3 %>% separate(sexage,c("sex","Age"),sep="(?<=[a-z])(?=[0-9])")
who4
# Out:
#       country     iso2 iso3 year new type sex Age  value
# 1     Afghanistan AF   AFG  1997 new sp   m   014    0
# 2     Afghanistan AF   AFG  1997 new sp   m   1524  10
# 3     Afghanistan AF   AFG  1997 new sp   m   2534   6
# 4     Afghanistan AF   AFG  1997 new sp   m   3544   3
# 5     Afghanistan AF   AFG  1997 new sp   m   4554   5
# 6     Afghanistan AF   AFG  1997 new sp   m   5564   2
# 7     Afghanistan AF   AFG  1997 new sp   m   65     0
# 8     Afghanistan AF   AFG  1997 new sp   f   014    5
# 9     Afghanistan AF   AFG  1997 new sp   f   1524  38
# 10    Afghanistan AF   AFG  1997 new sp   f   2534  36
# 11    Afghanistan AF   AFG  1997 new sp   f   3544  14
# 12    Afghanistan AF   AFG  1997 new sp   f   4554   8
# 13    Afghanistan AF   AFG  1997 new sp   f   5564   0
# 14    Afghanistan AF   AFG  1997 new sp   f   65     1
# 15    Afghanistan AF   AFG  1998 new sp   m   014   30
# 16    Afghanistan AF   AFG  1998 new sp   m   1524 129
# ...

# %% [markdown]
# ## Q5

# %%
head(who4)
tail(who4)
# Out:
#   country     iso2 iso3 year new type sex Age  value
# 1 Afghanistan AF   AFG  1997 new sp   m   014   0
# 2 Afghanistan AF   AFG  1997 new sp   m   1524 10
# 3 Afghanistan AF   AFG  1997 new sp   m   2534  6
# 4 Afghanistan AF   AFG  1997 new sp   m   3544  3
# 5 Afghanistan AF   AFG  1997 new sp   m   4554  5
# 6 Afghanistan AF   AFG  1997 new sp   m   5564  2
#   country  iso2 iso3 year new type sex Age  value
# 1 Zimbabwe ZW   ZWE  2013 new rel  f   1524 2069
# 2 Zimbabwe ZW   ZWE  2013 new rel  f   2534 4649
# 3 Zimbabwe ZW   ZWE  2013 new rel  f   3544 3526
# 4 Zimbabwe ZW   ZWE  2013 new rel  f   4554 1453
# 5 Zimbabwe ZW   ZWE  2013 new rel  f   5564  811
# 6 Zimbabwe ZW   ZWE  2013 new rel  f   65    725

# %% [markdown]
# ## Q6

# %%
 write.csv(who4, "who.csv")

# %% [markdown]
# # Task 2

# %%
data(iris)
head(iris, 6)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %% [markdown]
# ## Q1 Calculating the mean, median and mode of sepal length

# %%
mean(iris$Sepal.Length, na.rm = TRUE) 
median(iris$Sepal.Length, na.rm = TRUE)
mfv(iris$Sepal.Length,na_rm=TRUE)
# Out:
# [1] 5.843333
# [1] 5.8
# [1] 5

# %% [markdown]
# ## Q2

# %%
min(iris$Sepal.Length,na_rm=TRUE)
max(iris$Sepal.Length,na_rm=TRUE) 
range(iris$Sepal.Length,na_rm=TRUE)
# Out:
# [1] 1
# [1] 7.9
# [1] 1.0 7.9

# %% [markdown]
# ## Q3

# %%
IQR(iris$Sepal.Length,na.rm=TRUE)
quantile(iris$Sepal.Length,na.rm=TRUE)
# Out:
# [1] 1.3
#   0%  25%  50%  75% 100%
#  4.3  5.1  5.8  6.4  7.9

# %% [markdown]
# ## Q4

# %%
var(iris$Sepal.Length, na.rm = TRUE) 
sd(iris$Sepal.Length, na.rm = TRUE)
# Out:
# [1] 0.6856935
# [1] 0.8280661

# %% [markdown]
# ## Q5

# %%
summary(iris$Sepal.Length)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.300   5.100   5.800   5.843   6.400   7.900

# %% [markdown]
# ## Q6

# %%
sapply(select(iris, -c('Species')), mean)
sapply(select(iris, -c('Species')), quantile, na.rm =TRUE)
# Out:
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width
#     5.843333     3.057333     3.758000     1.199333
#      Sepal.Length Sepal.Width Petal.Length Petal.Width
# 0%   4.3          2.0         1.00         0.1
# 25%  5.1          2.8         1.60         0.3
# 50%  5.8          3.0         4.35         1.3
# 75%  6.4          3.3         5.10         1.8
# 100% 7.9          4.4         6.90         2.5

# %% [markdown]
# ## Q7

# %%
hist(iris$Sepal.Length,main='Histogram for sepal length', xlab = 'Sepal Length', col = "Blue",border = "Yellow")
# Out:
# Plot with title "Histogram for sepal length"

# %% [markdown]
# ## Q8

# %%
boxplot(iris[,!(names(iris) %in% c('Species'))] )
# Out:
# plot without title

# %% [markdown]
# ## Q9

# %%
qqnorm(iris$Sepal.Length, pch = 1, frame = FALSE) 
qqline(iris$Sepal.Length, col = "green", lwd = 2)
# Out:
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# # Task-3

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %% [markdown]
# ## Q1

# %%
unique(mpg$manufacturer)

df_grp_manufacturer = mpg %>% group_by(manufacturer)  %>%
  summarise(city_mpg = mean(cty),
            high_waympb = mean(hwy),
            .groups = 'drop')

df_grp_manufacturer
df_manufacturer <- melt(df_grp_manufacturer[,c('manufacturer','city_mpg','high_waympb')],id.vars = 1)
df_manufacturer
# Out:
#  [1] "audi"       "chevrolet"  "dodge"      "ford"       "honda"
#  [6] "hyundai"    "jeep"       "land rover" "lincoln"    "mercury"
# [11] "nissan"     "pontiac"    "subaru"     "toyota"     "volkswagen"
#    manufacturer city_mpg high_waympb
# 1  audi         17.61111 26.44444
# 2  chevrolet    15.00000 21.89474
# 3  dodge        13.13514 17.94595
# 4  ford         14.00000 19.36000
# 5  honda        24.44444 32.55556
# 6  hyundai      18.64286 26.85714
# 7  jeep         13.50000 17.62500
# 8  land rover   11.50000 16.50000
# 9  lincoln      11.33333 17.00000
# 10 mercury      13.25000 18.00000
# 11 nissan       18.07692 24.61538
# 12 pontiac      17.00000 26.40000
# 13 subaru       19.28571 25.57143
# 14 toyota       18.52941 24.91176
# 15 volkswagen   20.92593 29.22222
#    manufacturer variable    value
# 1  audi         city_mpg    17.61111
# 2  chevrolet    city_mpg    15.00000
# 3  dodge        city_mpg    13.13514
# 4  ford         city_mpg    14.00000
# ...

# %%
ggplot(df_manufacturer,aes(x = variable,y = value)) +
  geom_bar(aes(fill = manufacturer),stat = "identity",position = "dodge") +
  ggtitle("Car brand vs best mpg in city and highway both") +  scale_y_log10()
# Out:
# plot without title

# %% [markdown]
# ## Q2

# %%
type_car <- mpg %>%group_by(displ, class) %>% summarise(city_mpg = min(cty), .groups = 'drop')
df_type_car
# Out:
# Error in eval(expr, envir, enclos): object 'df_type_car' not found
# Traceback:

# %%
ggplot(df_type_car, aes(x=class, y=city_mpg, fill = factor(displ))) + 
  geom_bar(stat = 'identity', position = 'dodge') +ggtitle("Lowest mpg in city regarding displ")+
  geom_text(aes(label = city_mpg), vjust = -0.2, size = 5, position = position_dodge(0.9))
# Out:
# Error in ggplot(df_type_car, aes(x = class, y = city_mpg, fill = factor(displ))): object 'df_type_car' not found
# Traceback:
#
# 1. ggplot(df_type_car, aes(x = class, y = city_mpg, fill = factor(displ)))

# %% [markdown]
# ## Q3

# %%
df_best_performance_car <- mpg %>%group_by(displ) %>% summarise(city_mpg = max(cty),hwy_mpg = max(hwy),  .groups = 'drop')
df_best_performance_car
# Out:
#    displ city_mpg hwy_mpg
# 1  1.6   28       33
# 2  1.8   28       37
# 3  1.9   35       44
# 4  2.0   22       31
# 5  2.2   21       29
# 6  2.4   22       31
# 7  2.5   23       32
# 8  2.7   17       24
# 9  2.8   18       26
# 10 3.0   19       26
# 11 3.1   18       27
# 12 3.3   19       28
# 13 3.4   15       19
# 14 3.5   19       29
# 15 3.6   17       26
# 16 3.7   15       19
# 17 3.8   18       28
# 18 3.9   14       17
# 19 4.0   17       26
# 20 4.2   16       23
# 21 4.4   12       18
# 22 4.6   15       23
# 23 4.7   14       19
# 24 5.0   13       17
# 25 5.2   11       17
# 26 5.3   16       25
# 27 5.4   14       20
# 28 5.6   12       18
# 29 5.7   16       26
# 30 5.9   11       15
# 31 6.0   12       17
# 32 6.1   11       14
# 33 6.2   16       26
# 34 6.5   14       17
# 35 7.0   15       24

# %%
melt_car_type <- melt(df_best_performance_car[,c('displ','city_mpg','hwy_mpg')],id.vars = 1)
melt_car_type
# Out:
#     displ variable value
# 1   1.6   city_mpg 28
# 2   1.8   city_mpg 28
# 3   1.9   city_mpg 35
# 4   2.0   city_mpg 22
# 5   2.2   city_mpg 21
# 6   2.4   city_mpg 22
# 7   2.5   city_mpg 23
# 8   2.7   city_mpg 17
# 9   2.8   city_mpg 18
# 10  3.0   city_mpg 19
# 11  3.1   city_mpg 18
# 12  3.3   city_mpg 19
# 13  3.4   city_mpg 15
# 14  3.5   city_mpg 19
# 15  3.6   city_mpg 17
# 16  3.7   city_mpg 15
# 17  3.8   city_mpg 18
# 18  3.9   city_mpg 14
# 19  4.0   city_mpg 17
# 20  4.2   city_mpg 16
# 21  4.4   city_mpg 12
# 22  4.6   city_mpg 15
# 23  4.7   city_mpg 14
# 24  5.0   city_mpg 13
# 25  5.2   city_mpg 11
# 26  5.3   city_mpg 16
# 27  5.4   city_mpg 14
# 28  5.6   city_mpg 12
# 29  5.7   city_mpg 16
# 30  5.9   city_mpg 11
# ... ...   ...      ...
# 41  2.4   hwy_mpg  31
# 42  2.5   hwy_mpg  32
# 43  2.7   hwy_mpg  24
# 44  2.8   hwy_mpg  26
# 45  3.0   hwy_mpg  26
# 46  3.1   hwy_mpg  27
# 47  3.3   hwy_mpg  28
# 48  3.4   hwy_mpg  19
# 49  3.5   hwy_mpg  29
# ...

# %%
ggplot(melt_car_type,aes(x = displ,y = value)) +
  geom_bar(aes(fill = variable),stat = "identity",position = "dodge") +ggtitle("Best mpg in both city and highway Regarding displ")+
  scale_y_log10()
# Out:
# plot without title

# %%
df_cat_by_cyl_typ = mpg %>% group_by(class)  %>%
  summarise(cyl = mean(cyl),
            .groups = 'drop')
 
df_cat_by_cyl_typ
ggplot(df_cat_by_cyl_typ, aes(class, cyl)) +
  ggtitle("Car class categorised by Cylinder and type ")+geom_col()
# Out:
#   class      cyl
# 1 2seater    8.000000
# 2 compact    4.595745
# 3 midsize    5.317073
# 4 minivan    5.818182
# 5 pickup     7.030303
# 6 subcompact 5.028571
# 7 suv        6.967742
# plot without title

# %%
df_grp_class = mpg %>% group_by(class)  %>%
  summarise(displ_mpg = mean(displ),
            hwy_mpg = mean(hwy),
            .groups = 'drop')

df_grp_class
melt_df_grp_class<- melt(df_grp_class[,c('class','displ_mpg', 'hwy_mpg')],id.vars = 1)
melt_df_grp_class
# Out:
#   class      displ_mpg hwy_mpg
# 1 2seater    6.160000  24.80000
# 2 compact    2.325532  28.29787
# 3 midsize    2.921951  27.29268
# 4 minivan    3.390909  22.36364
# 5 pickup     4.418182  16.87879
# 6 subcompact 2.660000  28.14286
# 7 suv        4.456452  18.12903
#    class      variable  value
# 1  2seater    displ_mpg  6.160000
# 2  compact    displ_mpg  2.325532
# 3  midsize    displ_mpg  2.921951
# 4  minivan    displ_mpg  3.390909
# 5  pickup     displ_mpg  4.418182
# 6  subcompact displ_mpg  2.660000
# 7  suv        displ_mpg  4.456452
# 8  2seater    hwy_mpg   24.800000
# 9  compact    hwy_mpg   28.297872
# 10 midsize    hwy_mpg   27.292683
# 11 minivan    hwy_mpg   22.363636
# 12 pickup     hwy_mpg   16.878788
# 13 subcompact hwy_mpg   28.142857
# 14 suv        hwy_mpg   18.129032

# %%
ggplot(melt_df_grp_class,aes(x = class,y = value)) +ggtitle( 'car who have High liter vehical and drive mostly in highway')+
  geom_bar(aes(fill = variable),stat = "identity",position = "dodge") +
  scale_y_log10()
# Out:
# plot without title
